# %% [markdown]
# # Industrial Predictive Maintenance
# This notebook executes the tested end-to-end pipeline and reviews its verified outputs.

# %%
from pathlib import Path
import subprocess, sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
subprocess.run([sys.executable, str(ROOT / 'run_pipeline.py')], check=True)

# %%
import json
metrics = json.loads((ROOT / 'reports' / 'metrics.json').read_text())
metrics

# %%
from IPython.display import Image, display
for name in ['model_comparison.png', 'heldout_curves.png', 'threshold_cost.png', 'confusion_matrix.png', 'permutation_importance.png']:
    display(Image(filename=str(ROOT / 'reports' / 'figures' / name)))
